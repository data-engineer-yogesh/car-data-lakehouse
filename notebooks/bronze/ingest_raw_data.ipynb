# %% [markdown]
# ### Read From CSV and Write Bronze Raw data Table (1:1 copy)

# %% [markdown]
# This is testing select data from csv

# %%
# %sql
SELECT *
FROM csv.`/Volumes/cardatalakehouse_cat/landing/source_data/dim_dealer.csv`

# %% [markdown]
# load "dim_dealer.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/cardatalakehouse_cat/landing/source_data/dim_dealer.csv', header=True)
df.write.mode("overwrite").saveAsTable("cardatalakehouse_cat.bronze.dim_dealer_info")

# %% [markdown]
# Read data from cardatalakehouse_cat.bronze.dim_dealer_info for testing purposes; validation has been completed successfully.

# %%
# %sql
SELECT * FROM cardatalakehouse_cat.bronze.dim_dealer_info;

# %% [markdown]
# load "dim_car.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/cardatalakehouse_cat/landing/source_data/dim_car.csv', header=True)
df.write.mode("overwrite").saveAsTable("cardatalakehouse_cat.bronze.dim_car_info")

# %% [markdown]
# load "dim_date.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/cardatalakehouse_cat/landing/source_data/dim_date.csv', header=True)
df.write.mode("overwrite").saveAsTable("cardatalakehouse_cat.bronze.dim_date_info")

# %% [markdown]
# load "dim_inventory.csv

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/cardatalakehouse_cat/landing/source_data/dim_inventory.csv', header=True)
df.write.mode("overwrite").saveAsTable("cardatalakehouse_cat.bronze.dim_inventory_info")

# %% [markdown]
# load "dim_review.csv

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/cardatalakehouse_cat/landing/source_data/dim_review.csv', header=True)
df.write.mode("overwrite").saveAsTable("cardatalakehouse_cat.bronze.dim_review_info")

# %% [markdown]
# load "fact_sales.csv

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/cardatalakehouse_cat/landing/source_data/fact_sales.csv', header=True)
df.write.mode("overwrite").saveAsTable("cardatalakehouse_cat.bronze.fact_sales_info")
