# %% [markdown]
# Cleaning Tasks

# %% [markdown]
# Trim spaces
# - TRIM(model)
# - TRIM(dealer_name)

# %% [markdown]
# Standardize casing
# - LOWER(brand)
# - UPPER(car_id)

# %% [markdown]
# Handle nulls
# - drop null car_id
# - fill missing price

# %% [markdown]
# Fix date formats
# - convert both:
# -                 YYYY-MM-DD
# -                 DD/MM/YYYY

# %% [markdown]
# Remove duplicates
# - ROW_NUMBER() OVER (PARTITION BY sale_id)

# %% [markdown]
# Save change for Gold Layer
